# %% [markdown]
# # Homework 8 - Assignment 1
# This notebook generates data that counts Uber rides that originated from corresponding PUMA. The final data will look like this:

# %% [markdown]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>3701</th>
#       <th>3702</th>
#       <th>3703</th>
#       <th>3704</th>
#       <th>3705</th>
#       <th>3706</th>
#       <th>3707</th>
#       <th>3708</th>
#       <th>3709</th>
#       <th>3710</th>
#       <th>3801</th>
#       <th>3802</th>
#       <th>3803</th>
#       <th>3804</th>
#       <th>3805</th>
#       <th>3806</th>
#       <th>3807</th>
#       <th>3808</th>
#       <th>3809</th>
#       <th>3810</th>
#       <th>3901</th>
#       <th>3902</th>
#       <th>3903</th>
#       <th>4001</th>
#       <th>4002</th>
#       <th>4003</th>
#       <th>4004</th>
#       <th>4005</th>
#       <th>4006</th>
#       <th>4007</th>
#       <th>4008</th>
#       <th>4009</th>
#       <th>4010</th>
#       <th>4011</th>
#       <th>4012</th>
#       <th>4013</th>
#       <th>4014</th>
#       <th>4015</th>
#       <th>4016</th>
#       <th>4017</th>
#       <th>4018</th>
#       <th>4101</th>
#       <th>4102</th>
#       <th>4103</th>
#       <th>4104</th>
#       <th>4105</th>
#       <th>4106</th>
#       <th>4107</th>
#       <th>4108</th>
#       <th>4109</th>
#       <th>4110</th>
#       <th>4111</th>
#       <th>4112</th>
#       <th>4113</th>
#       <th>4114</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-08-01 00:00:00</th>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>5</td>
#       <td>5</td>
#       <td>7</td>
#       <td>4</td>
#       <td>22</td>
#       <td>10</td>
#       <td>178</td>
#       <td>49</td>
#       <td>72</td>
#       <td>162</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>62</td>
#       <td>18</td>
#       <td>7</td>
#       <td>16</td>
#       <td>17</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>4</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>16</td>
#       <td>0</td>
#       <td>2</td>
#       <td>3</td>
#       <td>9</td>
#       <td>1</td>
#       <td>0</td>
#       <td>4</td>
#       <td>5</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2014-08-01 00:00:00</th>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>5</td>
#       <td>5</td>
#       <td>7</td>
#       <td>4</td>
#       <td>22</td>
#       <td>10</td>
#       <td>178</td>
#       <td>49</td>
#       <td>72</td>
#       <td>162</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>62</td>
#       <td>18</td>
#       <td>7</td>
#       <td>16</td>
#       <td>17</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>4</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>16</td>
#       <td>0</td>
#       <td>2</td>
#       <td>3</td>
#       <td>9</td>
#       <td>1</td>
#       <td>0</td>
#       <td>4</td>
#       <td>5</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2014-08-01 01:00:00</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>5</td>
#       <td>3</td>
#       <td>1</td>
#       <td>14</td>
#       <td>14</td>
#       <td>108</td>
#       <td>29</td>
#       <td>56</td>
#       <td>94</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>33</td>
#       <td>13</td>
#       <td>3</td>
#       <td>10</td>
#       <td>5</td>
#       <td>6</td>
#       <td>1</td>
#       <td>0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>6</td>
#       <td>0</td>
#       <td>2</td>
#       <td>2</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>4</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>3</td>
#       <td>3</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2014-08-01 01:00:00</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>5</td>
#       <td>3</td>
#       <td>1</td>
#       <td>14</td>
#       <td>14</td>
#       <td>108</td>
#       <td>29</td>
#       <td>56</td>
#       <td>94</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>33</td>
#       <td>13</td>
#       <td>3</td>
#       <td>10</td>
#       <td>5</td>
#       <td>6</td>
#       <td>1</td>
#       <td>0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>6</td>
#       <td>0</td>
#       <td>2</td>
#       <td>2</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>4</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>3</td>
#       <td>3</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2014-08-01 02:00:00</th>
#       <td>1</td>
#       <td>2</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>3</td>
#       <td>6</td>
#       <td>2</td>
#       <td>1</td>
#       <td>12</td>
#       <td>11</td>
#       <td>62</td>
#       <td>12</td>
#       <td>32</td>
#       <td>65</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>19</td>
#       <td>10</td>
#       <td>5</td>
#       <td>5</td>
#       <td>3</td>
#       <td>4</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>7</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
#   </table>

# %% [markdown]
# We will use 2014 Aug Uber Rideship data published by FiveThirtyEight, and PUMA shapefile as basic geographical boundaries

# %% [markdown]
# ### This is work of **Sung Hoon Yang**

# %%
from __future__ import print_function
# this is me
__author__ = "Sung Hoon Yang, CUSP NYU 2018"

# limit the number of same warnings to once
import warnings
warnings.filterwarnings(action='once')

## bread and butter
import sys
import numpy as np
import pandas as pd
import matplotlib
font = {'weight' : 'bold',
        'size'   : 88}

matplotlib.rc('font', **font)
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sns
import os
"""
Set up PUIDATA env var
"""
os.environ["PUIDATA"] = "%s/fall18/PUI/PUIDATA"% os.getenv("HOME")
os.environ["PUI2018"] = "%s/fall18/PUI/PUI2018"% os.getenv("HOME")
# %matplotlib inline
np.random.seed(999)

# Utilities
sys.path.insert(0, '/nfshome/shy256/util')
from puma_to_name import PUMA_TO_NAME
from pprint import pprint
import re
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from copy import deepcopy
import geopandas as gpd
# Out:
# /nfshome/shy256/.conda/envs/tf/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /nfshome/shy256/.conda/envs/tf/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /nfshome/shy256/.conda/envs/tf/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /nfshome/shy256/.conda/envs/tf/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# additional geopandas stuff 
from shapely.geometry.point import Point
from geopandas import sjoin

# %% [markdown]
# ## DATA SETS
# 1. PUMA for land boundaries
# 2. UBER ride data

# %%
# My files reside here
__DATA_DIR__ = '/nfshome/shy256/fall18/USA/project2/dat'
__RAW_PUMA_SHP_PATH__ = os.path.join(__DATA_DIR__, 'puma_shp/geo_export_eb680ad3-bc49-498d-be16-c03226932b9c.shp')
__RAW_UBER_AUG14__ = os.path.join(__DATA_DIR__, 'uber-tlc-foil-response/uber-trip-data/uber-raw-data-aug14.csv')

# %% [markdown]
# ### Wrangling Uber Data first
# #### Turn the DataFrame __RAW_UBER_AUG14__ into GeoDataFrame

# %%
__RAW_UBER_AUG14_DF__ = pd.read_csv(__RAW_UBER_AUG14__)
__RAW_UBER_AUG14_DF__.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  8/1/2014 0:03:00  40.7366 -73.9906  B02512
# 1  8/1/2014 0:09:00  40.7260 -73.9918  B02512
# 2  8/1/2014 0:12:00  40.7209 -74.0507  B02512
# 3  8/1/2014 0:12:00  40.7387 -73.9856  B02512
# 4  8/1/2014 0:12:00  40.7323 -74.0077  B02512

# %%
_crs = {'init' : 'epsg:4326'}
_points = [Point(row[1][2], row[1][1]) for row in __RAW_UBER_AUG14_DF__.iterrows()]

uber_aug14_gdf = gpd.GeoDataFrame(__RAW_UBER_AUG14_DF__, crs=_crs, geometry=_points)
uber_aug14_gdf.head()
# Out:
#           Date/Time      Lat      Lon    Base  \
# 0  8/1/2014 0:03:00  40.7366 -73.9906  B02512
# 1  8/1/2014 0:09:00  40.7260 -73.9918  B02512
# 2  8/1/2014 0:12:00  40.7209 -74.0507  B02512
# 3  8/1/2014 0:12:00  40.7387 -73.9856  B02512
# 4  8/1/2014 0:12:00  40.7323 -74.0077  B02512
#
#                              geometry
# 0            POINT (-73.9906 40.7366)
# 1             POINT (-73.9918 40.726)
# 2  POINT (-74.05070000000001 40.7209)
# 3  POINT (-73.98560000000001 40.7387)
# 4            POINT (-74.0077 40.7323)

# %% [markdown]
# #### PUMA SHAPEFILE Exploration

# %%
__RAW_PUMA_SHP_GDF__ = gpd.read_file(__RAW_PUMA_SHP_PATH__)
__RAW_PUMA_SHP_GDF__['puma'] = __RAW_PUMA_SHP_GDF__['puma'].apply(int)
__RAW_PUMA_SHP_GDF__.head()
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002302
# 2  3703  2.670137e+08  304071.257466
# 3  3704  1.062129e+08   47970.901277
# 4  4015  8.105438e+07   50007.415493
#
#                                             geometry
# 0  POLYGON ((-73.89641133483133 40.90450452082026...
# 1  POLYGON ((-73.8442314689986 40.86942035096838,...
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...
# 4  POLYGON ((-73.95374853778468 40.63858633758547...

# %%
ax = __RAW_PUMA_SHP_GDF__.plot(color='white', edgecolor='black', figsize=(16, 12))
_coords = __RAW_PUMA_SHP_GDF__['geometry'].apply(lambda x: x.representative_point().coords[:])
_coords = [_coords[0] for _coords in _coords]

for idx, row in __RAW_PUMA_SHP_GDF__.iterrows():
    plt.annotate(s=row['puma'], xy=_coords[idx],
                 horizontalalignment='center')

ax.set_ylabel("latitude", fontsize=20)
ax.set_xlabel("longitude", fontsize=20)
# Out:
# Text(0.5,87,'longitude')

# %% [markdown]
# #### Perform spatial join on puma shapefile with uber ride lat/lon
#
# Final Output I want is as follows:

# %%
__RIDE_FROM_PUMA__ = sjoin(uber_aug14_gdf, __RAW_PUMA_SHP_GDF__, how='left',op="within")
__RIDE_FROM_PUMA__.head()
# Out:
#           Date/Time      Lat      Lon    Base  \
# 0  8/1/2014 0:03:00  40.7366 -73.9906  B02512
# 1  8/1/2014 0:09:00  40.7260 -73.9918  B02512
# 2  8/1/2014 0:12:00  40.7209 -74.0507  B02512
# 3  8/1/2014 0:12:00  40.7387 -73.9856  B02512
# 4  8/1/2014 0:12:00  40.7323 -74.0077  B02512
#
#                              geometry  index_right    puma    shape_area  \
# 0            POINT (-73.9906 40.7366)         22.0  3807.0  8.560261e+07
# 1             POINT (-73.9918 40.726)         24.0  3809.0  4.869347e+07
# 2  POINT (-74.05070000000001 40.7209)          NaN     NaN           NaN
# 3  POINT (-73.98560000000001 40.7387)         23.0  3808.0  4.498784e+07
# 4            POINT (-74.0077 40.7323)         25.0  3810.0  8.104639e+07
#
#       shape_leng
# 0   72181.026886
# 1   35299.804402
# 2            NaN
# 3   44430.927768
# 4  122921.903883

# %%
def process_dt(s):
    dt, t = tuple(s.split())
    mo, d, y = tuple([int(e) for e in dt.split('/')]) 
    h, m, s = tuple([int(e) for e in t.split(':')])
    return datetime(year=y, month=mo, day=d, hour=h, minute=m, second=s)
__RIDE_FROM_PUMA__['dt'] = __RIDE_FROM_PUMA__['Date/Time'].apply(process_dt)
__RIDE_FROM_PUMA__.head()
# Out:
#           Date/Time      Lat      Lon    Base  \
# 0  8/1/2014 0:03:00  40.7366 -73.9906  B02512
# 1  8/1/2014 0:09:00  40.7260 -73.9918  B02512
# 2  8/1/2014 0:12:00  40.7209 -74.0507  B02512
# 3  8/1/2014 0:12:00  40.7387 -73.9856  B02512
# 4  8/1/2014 0:12:00  40.7323 -74.0077  B02512
#
#                              geometry  index_right    puma    shape_area  \
# 0            POINT (-73.9906 40.7366)         22.0  3807.0  8.560261e+07
# 1             POINT (-73.9918 40.726)         24.0  3809.0  4.869347e+07
# 2  POINT (-74.05070000000001 40.7209)          NaN     NaN           NaN
# 3  POINT (-73.98560000000001 40.7387)         23.0  3808.0  4.498784e+07
# 4            POINT (-74.0077 40.7323)         25.0  3810.0  8.104639e+07
#
#       shape_leng                  dt
# 0   72181.026886 2014-08-01 00:03:00
# 1   35299.804402 2014-08-01 00:09:00
# 2            NaN 2014-08-01 00:12:00
# 3   44430.927768 2014-08-01 00:12:00
# 4  122921.903883 2014-08-01 00:12:00

# %% [markdown]
# ##### I need these columns for groupby time dim

# %%
__RIDE_FROM_PUMA__['date'] = __RIDE_FROM_PUMA__['dt'].apply(lambda ts: ts.date())
__RIDE_FROM_PUMA__['hour'] = __RIDE_FROM_PUMA__['dt'].apply(lambda ts: ts.hour)

# %% [markdown]
# ##### groupby time dimension with granularity of an hour, and count rides

# %%
__RIDE_FROM_PUMA_GRPBY__ = __RIDE_FROM_PUMA__.groupby(['puma', 'date', 'hour']).count()

# %%
__RIDE_FROM_PUMA_GRPBY__.drop(labels=[c for c in __RIDE_FROM_PUMA_GRPBY__.columns[1:]], axis=1, inplace=True)
__RIDE_FROM_PUMA_GRPBY__.head()
# Out:
#                         Date/Time
# puma   date       hour
# 3701.0 2014-08-01 2             1
#                   4             1
#                   5             2
#                   6             3
#                   7             2

# %% [markdown]
# ##### Iterate through all PUMAs and Merge the respective puma's hourly rideship count to the DataFrame RIDE_CNT_BY_PUMA

# %%
RIDE_CNT_BY_PUMA = pd.DataFrame(
    index=[datetime(year=2014, month=8, day=1, hour=0) + timedelta(days=h//24, hours=h%24) for h in range(24 * 31)]
)
for puma in __RIDE_FROM_PUMA_GRPBY__.index.levels[0]:
    _df = __RIDE_FROM_PUMA_GRPBY__.loc[puma]
    _ix = [ts + relativedelta(hour=hr) for ts, hr in _df.index]
    _df.index = _ix
    _df.rename(mapper={'Date/Time': int(puma)}, inplace=True, axis=1)
    RIDE_CNT_BY_PUMA = RIDE_CNT_BY_PUMA.merge(_df, how='left', left_index=True, right_index=True)

RIDE_CNT_BY_PUMA = RIDE_CNT_BY_PUMA.fillna(0)
for c in RIDE_CNT_BY_PUMA.columns:
    RIDE_CNT_BY_PUMA[c] = RIDE_CNT_BY_PUMA[c].apply(int)
RIDE_CNT_BY_PUMA.head()
# Out:
#                      3701  3702  3703  3704  3705  3706  3707  3708  3709  \
# 2014-08-01 00:00:00     0     0     1     0     0     1     0     1     0
# 2014-08-01 01:00:00     0     0     0     0     0     0     0     0     1
# 2014-08-01 02:00:00     1     2     0     1     1     0     0     0     0
# 2014-08-01 03:00:00     0     0     0     0     1     0     0     1     0
# 2014-08-01 04:00:00     1     1     0     0     0     1     0     1     0
#
#                      3710  ...   4105  4106  4107  4108  4109  4110  4111  \
# 2014-08-01 00:00:00     0  ...      9     1     0     4     5     1     0
# 2014-08-01 01:00:00     0  ...      2     0     0     0     3     3     3
# 2014-08-01 02:00:00     1  ...      2     0     2     0     7     1     1
# 2014-08-01 03:00:00     1  ...      1     0     0     2     4     2     1
# 2014-08-01 04:00:00     0  ...     25     1     2     1     4     2     0
#
#                      4112  4113  4114
# ...

# %%
ax = RIDE_CNT_BY_PUMA.sum(axis=0).plot(
    kind='bar'
    , color='red'
    , title ="Number of Rides in Aug. 2014"
    , figsize=(15,10)
    , fontsize=12
)

# %% [markdown]
# ## Let's bring in Demographic, Economic Data
# #### first, I want to standardize the ride count by population, and then compare it with income per capita

# %%
_econ = pd.read_excel(os.path.join(os.getenv("PUIDATA"), 'ACS2012-2016PUMA', 'econ_2016acs5yr_puma.xlsx'))
_demo = pd.read_excel(os.path.join(os.getenv("PUIDATA"), 'ACS2012-2016PUMA', 'demo_2016acs5yr_puma.xlsx'))
_hous = pd.read_excel(os.path.join(os.getenv("PUIDATA"), 'ACS2012-2016PUMA', 'hous_2016acs5yr_puma.xlsx'))
_soc = pd.read_excel(os.path.join(os.getenv("PUIDATA"), 'ACS2012-2016PUMA', 'soc_2016acs5yr_puma.xlsx'))
_demo.head()
# Out:
#     GeoType                                           GeogName  GeoID  \
# 0  PUMA2010  NYC-Brooklyn Community District 1--Greenpoint ...   4001
# 1  PUMA2010  NYC-Brooklyn Community District 4--Bushwick PU...   4002
# 2  PUMA2010  NYC-Brooklyn Community District 3--Bedford-Stu...   4003
# 3  PUMA2010  NYC-Brooklyn Community District 2--Brooklyn He...   4004
# 4  PUMA2010  NYC-Brooklyn Community District 6--Park Slope,...   4005
#
#     Borough  Pop_1E  Pop_1M  Pop_1C  Pop_1P  Pop_1Z  MaleE   ...     AsnOAsnE  \
# 0  Brooklyn  157433    2644     1.0     100     NaN  78095   ...          200
# 1  Brooklyn  135837    3022     1.4     100     NaN  67768   ...           17
# 2  Brooklyn  142689    2723     1.2     100     NaN  67613   ...           56
# 3  Brooklyn  135679    2054     0.9     100     NaN  64316   ...          143
# 4  Brooklyn  116344    1738     0.9     100     NaN  55601   ...           71
#
# ...

# %%
_econ.head()
# Out:
#     GeoType                                           GeogName  GeoID  \
# 0  PUMA2010  NYC-Brooklyn Community District 1--Greenpoint ...   4001
# 1  PUMA2010  NYC-Brooklyn Community District 4--Bushwick PU...   4002
# 2  PUMA2010  NYC-Brooklyn Community District 3--Bedford-Stu...   4003
# 3  PUMA2010  NYC-Brooklyn Community District 2--Brooklyn He...   4004
# 4  PUMA2010  NYC-Brooklyn Community District 6--Park Slope,...   4005
#
#     Borough  Pop16plE  Pop16plM  Pop16plC  Pop16plP  Pop16plZ    LFE  \
# 0  Brooklyn    126497      1788       0.9       100       NaN  88056
# 1  Brooklyn    109462      2315       1.3       100       NaN  75750
# 2  Brooklyn    108975      1811       1.0       100       NaN  70683
# 3  Brooklyn    114110      1709       0.9       100       NaN  79315
# 4  Brooklyn     95016      1529       1.0       100       NaN  72505
#
#      ...     Pv400t499E  Pv400t499M  Pv400t499C  Pv400t499P  Pv400t499Z  \
# ...

# %%
direction = pd.read_excel(os.path.join(os.getenv("PUIDATA"), 'ACS2012-2016PUMA', 'econ_2016acs5yr_puma.xlsx'), sheet_name=1).head(10)
direction
# Out:
#                    Selected Economic Characteristics Unnamed: 1 Unnamed: 2  \
# 0                                                NaN        NaN        NaN
# 1  *Note: Variables have codes represented below ...        NaN        NaN
# 2              Each variable is represented by fi...        NaN        NaN
# 3                          Field headings ending in:        NaN        NaN
# 4                                    "E" = estimates        NaN        NaN
# 5                             "M" = margins of error        NaN        NaN
# 6                    "C" = coefficients of variation        NaN        NaN
# 7                                     "P" = percents        NaN        NaN
# 8                     "Z" = percent margins of error        NaN        NaN
# 9              Where database cells are blank, nu...        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# ...

# %%
_econ_d = pd.read_excel(os.path.join(os.getenv("PUIDATA"), 'ACS2012-2016PUMA', 'econ_2016acs5yr_puma.xlsx'), sheet_name=1, header=11)
_demo_d = pd.read_excel(os.path.join(os.getenv("PUIDATA"), 'ACS2012-2016PUMA', 'demo_2016acs5yr_puma.xlsx'), sheet_name=1, header=11)
_hous_d = pd.read_excel(os.path.join(os.getenv("PUIDATA"), 'ACS2012-2016PUMA', 'hous_2016acs5yr_puma.xlsx'), sheet_name=1, header=11)
_soc_d = pd.read_excel(os.path.join(os.getenv("PUIDATA"), 'ACS2012-2016PUMA', 'soc_2016acs5yr_puma.xlsx'), sheet_name=1, header=11)

# %%
_soc_d.head(3)
# Out:
#                          Variable      Code Source(s) Start Column  \
# 0               Type of Geography   GeoType   Pop Div            A
# 1  Public Use Microdata Area Name  GeogName   Pop Div            B
# 2  Public Use Microdata Area Code     GeoID   Pop Div            C
#
#   Unit of Analysis
# 0              NaN
# 1              NaN
# 2              NaN

# %%
_hous_d.head(3)
# Out:
#                          Variable      Code Source(s) Start Column  \
# 0               Type of Geography   GeoType   Pop Div            A
# 1  Public Use Microdata Area Name  GeogName   Pop Div            B
# 2  Public Use Microdata Area Code     GeoID   Pop Div            C
#
#   Unit of Analysis
# 0              NaN
# 1              NaN
# 2              NaN

# %%
_demo_d.head(30)
# Out:
#                           Variable      Code Source(s) Start Column  \
# 0                Type of Geography   GeoType   Pop Div            A
# 1   Public Use Microdata Area Name  GeogName   Pop Div            B
# 2   Public Use Microdata Area Code     GeoID   Pop Div            C
# 3                          Borough   Borough   Pop Div            D
# 4                      SEX AND AGE       NaN       NaN          NaN
# 5                 Total population     Pop_1      DP05            E
# 6                             Male      Male      DP05            J
# 7                           Female       Fem      DP05            O
# 8                              NaN       NaN       NaN          NaN
# 9                    Under 5 years     PopU5      DP05            T
# 10                    5 to 9 years    Pop5t9      DP05            Y
# 11                  10 to 14 years  Pop10t14      DP05           AD
# 12                  15 to 19 years  Pop15t19      DP05           AI
# ...

# %%
_df2 = pd.DataFrame(_demo['Pop_1E'], index=[int(c) for c in _demo['GeoID']])
# _df2.index = [int(c) for c in _demo['GeoID']]
_df2
# _df = _df.merge(_df2, how='left', left_index=True, right_index=True)
# Out:
#       Pop_1E
# 4001     NaN
# 4002     NaN
# 4003     NaN
# 4004     NaN
# 4005     NaN
# 4006     NaN
# 4007     NaN
# 4008     NaN
# 4009     NaN
# 4010     NaN
# 4011     NaN
# 4012     NaN
# 4013     NaN
# 4014     NaN
# 4015     NaN
# 4016     NaN
# 4017     NaN
# 4018     NaN
# 3801     NaN
# 3802     NaN
# 3803     NaN
# 3804     NaN
# 3805     NaN
# 3806     NaN
# 3807     NaN
# 3808     NaN
# 3809     NaN
# 3810     NaN
# 4101     NaN
# 4102     NaN
# 4103     NaN
# 4104     NaN
# 4105     NaN
# 4106     NaN
# 4107     NaN
# 4108     NaN
# 4109     NaN
# 4110     NaN
# 4111     NaN
# 4112     NaN
# 4113     NaN
# 4114     NaN
# 3901     NaN
# 3902     NaN
# 3903     NaN
# 3701     NaN
# 3702     NaN
# 3703     NaN
# 3704     NaN
# 3705     NaN
# 3706     NaN
# 3707     NaN
# 3708     NaN
# 3709     NaN
# 3710     NaN

# %%
_df = pd.DataFrame(RIDE_CNT_BY_PUMA.sum(axis=0).T, index=[int(c) for c in RIDE_CNT_BY_PUMA.columns])

_df2 = pd.DataFrame(_demo['Pop_1E'])
_df2.index = [int(c) for c in _demo['GeoID']]
_df = _df.merge(_df2, how='left', left_index=True, right_index=True)

_df2 = pd.DataFrame(_econ['PerCapIncE'])
_df2.index = [int(c) for c in _econ['GeoID']]
_df = _df.merge(_df2, how='left', left_index=True, right_index=True)

_df.rename(mapper={0:'Uber Rides','Pop_1E': 'Total Population', 'PerCapIncE': 'Income Per Capita'}, axis=1, inplace=True)
_df.head()
# Out:
#       Uber Rides  Total Population  Income Per Capita
# 3701        1360            109810              32299
# 3702         321            144341              22134
# 3703         472            122417              29255
# 3704         629            129501              22824
# 3705         896            171849              12989

# %%
_df_std = pd.DataFrame(index=_df.index)
stdz = lambda col: 1.0 * (_df[col] - _df[col].mean()) / _df[col].std()
_df_std['Uber Rides'] = 1.0 * (_df['Uber Rides'] - _df['Uber Rides'].mean()) / _df['Uber Rides'].std()
_df_std['Total Population'] = 1.0 * (_df['Total Population'] - _df['Total Population'].mean()) / _df['Total Population'].std()
_df_std['Income Per Capita'] = 1.0 * (_df['Income Per Capita'] - _df['Income Per Capita'].mean()) / _df['Income Per Capita'].std()

_df_std.head()
# Out:
#       Uber Rides  Total Population  Income Per Capita
# 3701   -0.377110         -1.350980          -0.055972
# 3702   -0.406674         -0.291804          -0.498881
# 3703   -0.402377         -0.964283          -0.188605
# 3704   -0.397910         -0.746994          -0.468816
# 3705   -0.390312          0.551953          -0.897346

# %%
puma_to_boro = {	
	3701: 'Bronx',
	3702: 'Bronx',
	3703: 'Bronx',
	3704: 'Bronx',
	3705: 'Bronx',
	3706: 'Bronx',
	3707: 'Bronx',
	3708: 'Bronx',
	3709: 'Bronx',
	3710: 'Bronx',
	4001: 'Brooklyn',
	4002: 'Brooklyn',
	4003: 'Brooklyn',
	4004: 'Brooklyn',
	4005: 'Brooklyn',
	4006: 'Brooklyn',
	4007: 'Brooklyn',
	4008: 'Brooklyn',
	4009: 'Brooklyn',
	4010: 'Brooklyn',
	4011: 'Brooklyn',
	4012: 'Brooklyn',
	4013: 'Brooklyn',
	4014: 'Brooklyn',
	4015: 'Brooklyn',
	4016: 'Brooklyn',
	4017: 'Brooklyn',
	4018: 'Brooklyn',
	3801: 'Manhattan',
	3802: 'Manhattan',
	3803: 'Manhattan',
	3804: 'Manhattan',
	3805: 'Manhattan',
	3806: 'Manhattan',
	3807: 'Manhattan',
	3808: 'Manhattan',
	3809: 'Manhattan',
	3810: 'Manhattan',
	4101: 'Queens',
	4102: 'Queens',
	4103: 'Queens',
	4104: 'Queens',
	4105: 'Queens',
	4106: 'Queens',
	4107: 'Queens',
	4108: 'Queens',
	4109: 'Queens',
	4110: 'Queens',
	4111: 'Queens',
	4112: 'Queens',
	4113: 'Queens',
	4114: 'Queens',
	3901: 'Staten',
	3902: 'Staten',
	3903: 'Staten'}

# %%
_df_std['boro'] = pd.Series([puma_to_boro[ix] for ix in _df_std.index], index=_df_std.index)
_df_std.head()
# Out:
#       Uber Rides  Total Population  Income Per Capita   boro
# 3701   -0.377110         -1.350980          -0.055972  Bronx
# 3702   -0.406674         -0.291804          -0.498881  Bronx
# 3703   -0.402377         -0.964283          -0.188605  Bronx
# 3704   -0.397910         -0.746994          -0.468816  Bronx
# 3705   -0.390312          0.551953          -0.897346  Bronx

# %%
c_dict = dict(zip(_df_std.boro.unique(), ['r', 'g', 'b', 'y', 'k']))
c_dict
# Out:
# {'Bronx': 'r', 'Brooklyn': 'y', 'Manhattan': 'g', 'Queens': 'k', 'Staten': 'b'}

# %%
my_colors = pd.Series([c_dict[b] for b in _df_std['boro']], index=_df_std.index)

# %%
plt.cla()
plt.clf()

# %%
for c in _df_std.columns[1:2]:
    print(c)
    fig = plt.figure()
    for b in _df_std.boro.unique():
        ax = _df_std[c].plot.bar(rot=45, figsize=(16, 12),  color=my_colors)
        ax.set_xticklabels([PUMA_TO_NAME[c] for c in _df_std.index.tolist()], rotation=90, fontdict={'fontsize': 8})
        ax.set_ylabel('standardized value of %s' % c)
        ax.set_xlabel('PUMA Neighborhood Names')        
        ax.set_title('PUMA-wise Standardized %s' % c,  fontdict={'fontsize': 24})
        ax.text(10, 2
                , "COLOR LEGEND:\n\nBronx: 'Red'\n\nBrooklyn: 'Yellow'\n\nManhattan: 'Green'\n\nQueens: 'Black'\n\nStaten: 'Blue'\n"
               )
#         break
#     break
    fig.savefig("puma_vs%s.png" % c.replace(' ', '_'))
    plt.cla()
    plt.clf()
# Out:
# Total Population

# %%
## End of Notebook
